# %%
# buying
from time import sleep
import krakenex
from pykrakenapi import KrakenAPI
api = krakenex.API()
kraken = KrakenAPI(api)

api.load_key('KrakenPass.txt')

while True:

    closed_orders = kraken.get_closed_orders()[0]
    closed_orders[['descr_pair', 'descr_type', 'descr_ordertype', 'descr_price']]

    # iterate through the rows of closed orders table. need to obtain price of most recent buy order
    last_price = 0
    for ind in closed_orders.index:
        if closed_orders['descr_type'][ind] == 'buy':
            last_price = float(closed_orders['descr_price'][ind])
            # print(closed_orders['descr_price'][ind])
            break
    
    try:
        BTC_old = float((kraken.get_ticker_information('BTCCAD'))['b'][0][0])
    except exception as e:
        print(f'Unable to obtain BTC data: {e}')
    
    sleep(60)
    
    try:
        BTC_new = float((kraken.get_ticker_information('BTCCAD'))['b'][0][0])
    except exception as e:
        print(f'Unable to obtain BTC data: {e}')
    
    # percent = ((BTC_new - BTC_old)*100) / BTC_old # original percent
    percent = ((BTC_new - last_price)*100) / last_price # original percent
    
    # print("BTC Old: ", BTC_old)
    print("Last Price: ", last_price)
    print("BTC New: ", BTC_new)

    if (percent >= 0.0015) & (BTC_new < last_price):
        try:
            BTC = float((kraken.get_ticker_information('BTCCAD'))['a'][0][0]) + 2
            
            response = kraken.add_standard_order(pair='XXBTZCAD', type='buy', ordertype='limit', 
                                                 volume='0.0001', price=BTC, validate=False)
            print(response)
        except exception as e:
            print(f'Error placing order: {e}')
    
        sleep(3)
    
        check_order = kraken.query_orders_info(response['txid'][0])
    
        if check_order['status'][0] == 'open' or 'closed':
            print('Order completed sucessfully')
            break
        else:
            print('Order rejected')
            break
    else:
        print('Requirement not reached')
# Out:
# Last Price:  54074.5
# BTC New:  44364.6
# Requirement not reached
# public call frequency exceeded (seconds=0.384109)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44334.9
# Requirement not reached
# public call frequency exceeded (seconds=0.874728)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44376.8
# Requirement not reached
# public call frequency exceeded (seconds=0.384613)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44389.3
# Requirement not reached
# public call frequency exceeded (seconds=0.381068)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44396.6
# Requirement not reached
# public call frequency exceeded (seconds=0.416587)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44250.3
# Requirement not reached
# public call frequency exceeded (seconds=0.405182)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44295.2
# Requirement not reached
# public call frequency exceeded (seconds=0.838592)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44288.9
# Requirement not reached
# public call frequency exceeded (seconds=0.334913)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44290.6
# Requirement not reached
# public call frequency exceeded (seconds=0.343953)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44282.1
# Requirement not reached
# public call frequency exceeded (seconds=0.407945)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44205.6
# Requirement not reached
# public call frequency exceeded (seconds=0.43922)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44206.8
# Requirement not reached
# public call frequency exceeded (seconds=0.320763)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44173.2
# Requirement not reached
# public call frequency exceeded (seconds=0.364369)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44149.5
# Requirement not reached
# public call frequency exceeded (seconds=0.672075)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44170.9
# Requirement not reached
# public call frequency exceeded (seconds=0.647594)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44180.2
# Requirement not reached
# public call frequency exceeded (seconds=0.334002)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44219.2
# Requirement not reached
# public call frequency exceeded (seconds=0.391379)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44196.4
# Requirement not reached
# public call frequency exceeded (seconds=0.641738)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44154.3
# Requirement not reached
# public call frequency exceeded (seconds=0.612696)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44161.8
# Requirement not reached
# public call frequency exceeded (seconds=0.436639)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44141.9
# Requirement not reached
# public call frequency exceeded (seconds=0.401501)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44145.7
# Requirement not reached
# public call frequency exceeded (seconds=0.406117)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44202.4
# Requirement not reached
# public call frequency exceeded (seconds=0.483434)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44201.9
# Requirement not reached
# public call frequency exceeded (seconds=0.652154)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44158.4
# Requirement not reached
# public call frequency exceeded (seconds=0.862774)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44179.5
# Requirement not reached
# public call frequency exceeded (seconds=0.424551)
#  sleeping for 5 seconds
# Last Price:  54074.5
# BTC New:  44198.0
# Requirement not reached
# public call frequency exceeded (seconds=0.395545)
#  sleeping for 5 seconds

# %%
# selling
from time import sleep
import krakenex
from pykrakenapi import KrakenAPI
api = krakenex.API()
kraken = KrakenAPI(api)

api.load_key('KrakenPass.txt')

while True:
    closed_orders = kraken.get_closed_orders()[0]
    closed_orders[['descr_pair', 'descr_type', 'descr_ordertype', 'descr_price']]

    # iterate through the rows of closed orders table. need to obtain price of most recent buy order
    last_price = 0
    for ind in closed_orders.index:
        if closed_orders['descr_type'][ind] == 'buy':
            last_price = closed_orders['descr_price'][ind]
            # print(closed_orders['descr_price'][ind])
            break
    
    try:
        BTC_old = float((kraken.get_ticker_information('BTCCAD'))['b'][0][0])
    except exception as e:
        print(f'Unable to obtain BTC data: {e}')
    
    sleep(60)
    
    try:
        BTC_new = float((kraken.get_ticker_information('BTCCAD'))['b'][0][0])
    except exception as e:
        print(f'Unable to obtain BTC data: {e}')
    
    
    percent = ((BTC_new - BTC_old)*100) / BTC_old # original percent formula
    
    print("BTC Old: ", BTC_old)
    print("BTC New: ", BTC_new)
    if percent >= 0.0015:
        try:
            BTC = float((kraken.get_ticker_information('BTCCAD'))['a'][0][0]) + 2
            
            response = kraken.add_standard_order(pair='XXBTZCAD', type='sell', ordertype='limit', 
                                                 volume='0.0001', price=BTC, validate=False)
            print(response)
        except exception as e:
            print(f'Error placing order: {e}')
    
        sleep(3)
    
        check_order = kraken.query_orders_info(response['txid'][0])
    
        if check_order['status'][0] == 'open' or 'closed':
            print('Order completed sucessfully')
            break
        else:
            print('Order rejected')
            break
    else:
        print('Requirement not reached')
# Out:
# BTC Old:  54026.2
# BTC New:  54026.2
# Requirement not reached
# public call frequency exceeded (seconds=0.182288)
#  sleeping for 5 seconds
# BTC Old:  54026.2
# BTC New:  54050.1
# public call frequency exceeded (seconds=0.143667)
#  sleeping for 5 seconds
# {'txid': ['ONYBA7-3BVHS-DBJSUM'], 'descr': {'order': 'sell 0.00010000 XBTCAD @ limit 54093.5'}}
# Order completed sucessfully

# %%
# idea for obtaining closed orders
import krakenex
from pykrakenapi import KrakenAPI
api = krakenex.API()
kraken = KrakenAPI(api)
api.load_key('KrakenPass.txt')

closed_orders = kraken.get_closed_orders()[0]
closed_orders[['descr_pair', 'descr_type', 'descr_ordertype', 'descr_price']]

# iterate through the rows of closed orders table. need to obtain price of most recent buy order
for ind in closed_orders.index:
  if closed_orders['descr_type'][ind] == 'buy':
    print(closed_orders['descr_price'][ind])
    break
  # print(closed_orders['descr_type'][ind], closed_orders['descr_price'][ind])
# closed_orders
# Out:
# 54074.5

# %%
# current price
import krakenex
from pykrakenapi import KrakenAPI
api = krakenex.API()
kraken = KrakenAPI(api)
api.load_key('KrakenPass.txt')

last_trade = kraken.get_ticker_information('BTCCAD')['b'][0][0]
type(last_trade)
# Out:
# str
